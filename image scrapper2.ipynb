# %%
import requests
import logging
import os
from bs4 import BeautifulSoup
from urllib.request import urlopen

# %%
save_dir = "images1/"
if not os.path.exists(save_dir):
    os.makedirs(save_dir)

# %%
query = "salman khan"
#url = https://www.google.com/search?q={query}&rlz=1C1JJTC_enIN1060IN1060&tbm=isch&sxsrf=AB5stBioDFXm4Sr9kkohh1YXr1zZEtOHDA:1690995139382&source=lnms&sa=X&ved=2ahUKEwiL4eXkt76AAxUvtlYBHa4UCv4Q_AUoAnoECAIQBA&biw=1821&bih=868&dpr=0.75

# %%
response=requests.get(f"https://www.google.com/search?q={query}&rlz=1C1JJTC_enIN1060IN1060&tbm=isch&sxsrf=AB5stBioDFXm4Sr9kkohh1YXr1zZEtOHDA:1690995139382&source=lnms&sa=X&ved=2ahUKEwiL4eXkt76AAxUvtlYBHa4UCv4Q_AUoAnoECAIQBA&biw=1821&bih=868&dpr=0.75")

# %%
response
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(response.content,"html.parser")

# %%
soup
# Out:
# <!DOCTYPE html PUBLIC "-//WAPFORUM//DTD XHTML Mobile 1.0//EN" "http://www.wapforum.org/DTD/xhtml-mobile10.dtd">
# ...

# %%
image_tags=soup.find_all("img")

# %%
del image_tags[0]

# %%
len(image_tags)
# Out:
# 18

# %%
requests.get(f"https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQFK9WTG1XDdWap_7HpvzHMzb85UqaEa24dUD-NcxSzXPdRT9-RGOGAOioCaCc&amp").content
# Out:
# b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00\xff\xdb\x00\x84\x00\t\x06\x07\x08\x07\x06\t\x08\x07\x08\n\n\t\x0b\r\x16\x0f\r\x0c\x0c\r\x1b\x14\x15\x10\x16 \x1d"" \x1d\x1f\x1f$(4,$&1\'\x1f\x1f-=-157:::#+?D?8C49:7\x01\n\n\n\r\x0c\r\x1a\x0f\x0f\x1a7%\x1f%77777777777777777777777777777777777777777777777777\xff\xc0\x00\x11\x08\x00\x8c\x00N\x03\x01"\x00\x02\x11\x01\x03\x11\x01\xff\xc4\x00\x1b\x00\x00\x03\x00\x03\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x04\x05\x06\x02\x03\x07\x00\x01\xff\xc4\x00@\x10\x00\x02\x01\x03\x02\x03\x05\x04\x06\x08\x04\x07\x00\x00\x00\x00\x01\x02\x03\x00\x04\x11\x05!\x06\x121\x13AQaq\x14"\xb1\xc12R\x81\x91\xa1\xe1#$BCt\xd1\xf0\xf1\x163bd\x074cr\x82\x92\xa2\xff\xc4\x00\x19\x01\x00\x03\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x02\x03\x04\x01\x05\x00\xff\xc4\x00!\x11\x00\x02\x02\x02\x02\x02\x03\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x01\x02\x11\x03!\x121\x042"AQ3\xff\xda\x00\x0c\x03\x01\x00\x02\x11\x03\x11\x00?\x00\xac\xe3
# ...

# %%
save_dir = "images1/"
if not os.path.exists(save_dir):
    os.makedirs(save_dir)

# %%
for i in image_tags:
    image_url=i["src"]
    image_data=requests.get(image_url).content
    with open(os.path.join(save_dir,f"{query}_{image_tags.index(i)}.jpg"),"wb") as f:
        f.write(image_data)
